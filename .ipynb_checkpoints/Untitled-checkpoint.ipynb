# %%
import uproot
import pandas as pd
from itertools import chain, product
import time
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as spstat
from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# # Pad-clutering based on graph connectivity
#
# - Each node is a hit, defined by the x-y coordinate of the readout pad.
# - Node A is connected to node B, if the distance between them is 1 cm.
# - A is linked to B is there is a path of connected nodes from A to B.

# %%
x = np.array([1,1,1,1,2,6])
y = np.array([1,2,3,4,3,5])
p = np.dstack([x,y])[0]
print(p)
# Out:
# [[1 1]
#  [1 2]
#  [1 3]
#  [1 4]
#  [2 3]
#  [6 5]]

# %%
from scipy.spatial.distance import cdist

# %%
A = 0
B = 2
# creating a map of connections
r = (cdist(p, p) == 1)
print(r)
connections = np.where(r)

# %%
class cluster:
    def __init__(self, x, y):
        self._points = np.dstack([x,y])[0]
        self._connections = np.where(cdist(self._points, self._points) == 1)
    
    def append(self, p):
        self._points = np.append(self._points, np.array([p]), axis=0)
        self._connections = np.where(cdist(self._points, self._points) == 1)
    
    def isLinked(self, a, b, history=np.array([])):
        children = self._connections[1][self._connections[0] == a]
        if children.shape[0] == 0:
            return False
        elif b in children:
            return True
        else:
            children = np.setdiff1d(children,history)
            ans = False

            new_hist =  np.concatenate((children, history))
            for child in children:
                ans = ans or self.isLinked(child, b, new_hist)
                if ans:
                    return ans
            return ans
    
    def seeding(self, p, radius=2):
        return np.where(cdist(np.array([p]), self._points) < radius)[1]
    
    def cluster(self, p, radius=2):
        source = seeding(p, radius)[0]
        members = []
        for i in range(cl._points.shape[1]):
            if i == 0:
                continue
            if cl.isLinked(0,i):
                members.append(cl._points[i])
        return members

# %%
cl = cluster(x,y)

# %%
for i in range(cl._points.shape[1]):
    if i == 0:
        continue
    if cl.isLinked(0,i):
        print(cl._points[i])
# Out:
# [1 2]

# %%
np.diff(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-37097dc637ff> in <module>
# ----> 1 np.diff(x,y)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/function_base.py in diff(a, n, axis, prepend, append)
#    1230
#    1231     """
# -> 1232     if n == 0:
#    1233         return a
#    1234     if n < 0:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
y
# Out:
# array([1, 2, 3, 4, 3, 5])

# %%
np.setdiff1d(x,y)
# Out:
# array([6])

# %%
bool(sum(r[0]))
# Out:
# True

# %%
np.concatenate((x,y))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-c9664ae5feea> in <module>
# ----> 1 np.concatenate((x,y)).unique
#
# AttributeError: 'numpy.ndarray' object has no attribute 'unique'

# %%
np.delete(x,np.where(x == 6))
# Out:
# array([1, 1, 1, 1, 2])

# %%
bool(2)
# Out:
# True

# %%
df = pd.read_csv('debug_df_mips.csv')

# %%
df
# Out:
#                                   eventId  chbid          xpos          ypos  \
# 0    11112018-2240-1_11112018-2240-1_1299      1  [26.0, 25.0]  [24.0, 24.0]
# 1    11112018-2240-1_11112018-2240-1_1299      2        [25.0]        [24.0]
# 2    11112018-2240-1_11112018-2240-1_1299      3        [25.0]        [24.0]
# 3    11112018-2240-1_11112018-2240-1_1299      4        [25.0]        [23.0]
# 4    11112018-2240-1_11112018-2240-1_1299      5        [25.0]        [23.0]
# ..                                    ...    ...           ...           ...
# 116   11112018-2240-1_11112018-2240-1_817      3        [26.0]        [28.0]
# 117   11112018-2240-1_11112018-2240-1_817      4        [26.0]        [28.0]
# 118   11112018-2240-1_11112018-2240-1_817      5        [26.0]        [28.0]
# 119   11112018-2240-1_11112018-2240-1_817      6        [26.0]        [28.0]
# 120   11112018-2240-1_11112018-2240-1_817      7        [26.0]        [28.0]
#
#                dt   digit  chipid  hardid  nhits
# 0    [15.0, 16.0]  [3, 3]  [4, 2]  [7, 0]      2
# 1          [15.0]     [3]     [2]     [0]      1
# 2          [16.0]     [2]     [2]     [0]      1
# 3          [16.0]     [2]    [17]    [63]      1
# 4          [16.0]     [2]    [17]    [63]      1
# ..            ...     ...     ...     ...    ...
# 116        [14.0]     [2]     [3]    [39]      1
# 117        [13.0]     [1]    [11]    [52]      1
# 118        [14.0]     [2]    [11]    [52]      1
# 119        [15.0]     [3]    [11]    [52]      1
# 120        [14.0]     [2]    [11]    [52]      1
#
# [121 rows x 9 columns]

# %%
df[df.chbid == 7][['eventId','xpos', 'ypos']]
# Out:
#                                   eventId          xpos          ypos
# 6    11112018-2240-1_11112018-2240-1_1299        [25.0]        [23.0]
# 20   11112018-2240-1_11112018-2240-1_1801        [26.0]        [27.0]
# 28   11112018-2240-1_11112018-2240-1_1859        [26.0]        [27.0]
# 50   11112018-2240-1_11112018-2240-1_2530        [26.0]        [23.0]
# 57   11112018-2240-1_11112018-2240-1_2555  [25.0, 26.0]  [27.0, 27.0]
# 64   11112018-2240-1_11112018-2240-1_2793        [26.0]        [24.0]
# 70   11112018-2240-1_11112018-2240-1_2869        [30.0]        [27.0]
# 78   11112018-2240-1_11112018-2240-1_2920        [25.0]        [25.0]
# 84   11112018-2240-1_11112018-2240-1_3390        [27.0]        [26.0]
# 92   11112018-2240-1_11112018-2240-1_3466        [28.0]        [21.0]
# 106  11112018-2240-1_11112018-2240-1_3991        [25.0]        [27.0]
# 113   11112018-2240-1_11112018-2240-1_588        [24.0]        [25.0]
# 120   11112018-2240-1_11112018-2240-1_817        [26.0]        [28.0]

# %%
x = df.xpos[(df.chbid == 7) & (df.eventId == '11112018-2240-1_11112018-2240-1_2555')]
y = df.ypos[(df.chbid == 7) & (df.eventId == '11112018-2240-1_11112018-2240-1_2555')]

str2strlist = lambda a: a.replace(']','').replace('[','').split(",") 
strlist2arrfloats = lambda lst: np.array([float(i) for i in lst])

x = x.agg(str2strlist).agg(strlist2arrfloats).iloc[0]
y = y.agg(str2strlist).agg(strlist2arrfloats).iloc[0]

# %%
x
# Out:
# array([25., 26.])

# %%
cl = cluster(x,y)

# %%
cl._points
# Out:
# array([[25., 27.],
#        [26., 27.]])

# %%
cl.append(p)

# %%
p = np.array([24,27])

# %%
cl._connections
# Out:
# (array([0, 1]), array([1, 0]))

# %%
searching = np.append(cl._points, np.array([p]), axis=0)
np.where(cdist(np.array([p]), cl._points) < 2)[1][0]
# Out:
# 0

# %%
for
# Out:
# (array([0, 1]), array([1, 0]))

# %%
def mut(daf):
    daf["new"] = daf.hardid.agg(lambda x: len(x))
    return None

# %%
mut(df)
df
# Out:
#                                   eventId  chbid          xpos          ypos  \
# 0    11112018-2240-1_11112018-2240-1_1299      1  [26.0, 25.0]  [24.0, 24.0]
# 1    11112018-2240-1_11112018-2240-1_1299      2        [25.0]        [24.0]
# 2    11112018-2240-1_11112018-2240-1_1299      3        [25.0]        [24.0]
# 3    11112018-2240-1_11112018-2240-1_1299      4        [25.0]        [23.0]
# 4    11112018-2240-1_11112018-2240-1_1299      5        [25.0]        [23.0]
# ..                                    ...    ...           ...           ...
# 116   11112018-2240-1_11112018-2240-1_817      3        [26.0]        [28.0]
# 117   11112018-2240-1_11112018-2240-1_817      4        [26.0]        [28.0]
# 118   11112018-2240-1_11112018-2240-1_817      5        [26.0]        [28.0]
# 119   11112018-2240-1_11112018-2240-1_817      6        [26.0]        [28.0]
# 120   11112018-2240-1_11112018-2240-1_817      7        [26.0]        [28.0]
#
#                dt   digit  chipid  hardid  nhits  new
# 0    [15.0, 16.0]  [3, 3]  [4, 2]  [7, 0]      2    6
# 1          [15.0]     [3]     [2]     [0]      1    3
# 2          [16.0]     [2]     [2]     [0]      1    3
# 3          [16.0]     [2]    [17]    [63]      1    4
# 4          [16.0]     [2]    [17]    [63]      1    4
# ..            ...     ...     ...     ...    ...  ...
# 116        [14.0]     [2]     [3]    [39]      1    4
# 117        [13.0]     [1]    [11]    [52]      1    4
# 118        [14.0]     [2]    [11]    [52]      1    4
# 119        [15.0]     [3]    [11]    [52]      1    4
# 120        [14.0]     [2]    [11]    [52]      1    4
#
# [121 rows x 10 columns]

# %%
dataId = 'eventId'
df_mip = df
# preparing for fit
tofit = df_mip.groupby(dataId).agg(lambda x: x.tolist())[['chbid', 'xpos', 'ypos', 'nhits']]

tofit_xyz = tofit[['xpos', 'ypos']]

# # Fitting track
# fit = pd.DataFrame({'zx': tofit_xyz[['chbid', 'xpos']].apply(tuple, axis=1),
#                 'zy': tofit_xyz[['chbid', 'ypos']].apply(tuple, axis=1)})
# tofit_xyz[['zx', 'zy']] = fit.applymap(lambda p: np.polyfit(p[0], p[1], 1))

# %%
tofit_xyz.loc['11112018-2240-1_11112018-2240-1_1299']
# Out:
# xpos    [[26.0, 25.0], [25.0], [25.0], [25.0], [25.0],...
# ypos    [[24.0, 24.0], [24.0], [24.0], [23.0], [23.0],...
# Name: 11112018-2240-1_11112018-2240-1_1299, dtype: object

# %%
df['new2'].loc[df.eventId == '11112018-2240-1_11112018-2240-1_1299']='yo'

# %%
df['new2'] = np.empty(len(df))

# %%
df
# Out:
#                                   eventId  chbid          xpos          ypos  \
# 0    11112018-2240-1_11112018-2240-1_1299      1  [26.0, 25.0]  [24.0, 24.0]
# 1    11112018-2240-1_11112018-2240-1_1299      2        [25.0]        [24.0]
# 2    11112018-2240-1_11112018-2240-1_1299      3        [25.0]        [24.0]
# 3    11112018-2240-1_11112018-2240-1_1299      4        [25.0]        [23.0]
# 4    11112018-2240-1_11112018-2240-1_1299      5        [25.0]        [23.0]
# ..                                    ...    ...           ...           ...
# 116   11112018-2240-1_11112018-2240-1_817      3        [26.0]        [28.0]
# 117   11112018-2240-1_11112018-2240-1_817      4        [26.0]        [28.0]
# 118   11112018-2240-1_11112018-2240-1_817      5        [26.0]        [28.0]
# 119   11112018-2240-1_11112018-2240-1_817      6        [26.0]        [28.0]
# 120   11112018-2240-1_11112018-2240-1_817      7        [26.0]        [28.0]
#
#                dt   digit  chipid  hardid  nhits new  new2
# 0    [15.0, 16.0]  [3, 3]  [4, 2]  [7, 0]      2  yo   0.0
# 1          [15.0]     [3]     [2]     [0]      1  yo   0.0
# 2          [16.0]     [2]     [2]     [0]      1  yo   0.0
# 3          [16.0]     [2]    [17]    [63]      1  yo   0.0
# 4          [16.0]     [2]    [17]    [63]      1  yo   0.0
# ..            ...     ...     ...     ...    ...  ..   ...
# 116        [14.0]     [2]     [3]    [39]      1   4   0.0
# 117        [13.0]     [1]    [11]    [52]      1   4   0.0
# 118        [14.0]     [2]    [11]    [52]      1   4   0.0
# 119        [15.0]     [3]    [11]    [52]      1   4   0.0
# 120        [14.0]     [2]    [11]    [52]      1   4   0.0
#
# [121 rows x 11 columns]

# %%
for i in range(df.shape[0]):
    p = [df.zx.iloc[i][0]*df.chbid.iloc[i] + df.zx.iloc[i][1],
         df.zy.iloc[i][0]*df.chbid.iloc[i] + df.zy.iloc[i][1]]
    print("x: {}".format(df.xpos.iloc[i]))
    print("y: {}".format(df.ypos.iloc[i]))
    cl = clustet(df.xpos.iloc[i], df.xpos.iloc[i]) 
    cl.seeding(p)
    df['cl_members'] = cl.cluster(p)
# Out:
# [26.0, 25.0]
# [25.0]
# [25.0]
# [25.0]
# [25.0]
# [25.0]
# [25.0]
# [24.0, 25.0]
# [25.0]
# [26.0, 25.0]
# [25.0]
# [25.0]
# [25.0]
# [25.0]
# [26.0, 25.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [27.0, 26.0]
# [27.0]
# [27.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0, 26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0, 26.0]
# [26.0]
# [26.0]
# [26.0, 26.0]
# [26.0]
# [26.0]
# [26.0]
# [27.0, 26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [25.0, 26.0]
# [26.0]
# [26.0]
# [25.0]
# [26.0]
# [26.0]
# [25.0, 26.0]
# [27.0, 26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [31.0, 30.0]
# [31.0]
# [30.0]
# [30.0]
# [30.0]
# [30.0]
# [31.0, 30.0]
# [25.0, 25.0]
# [25.0]
# [25.0]
# [25.0]
# [25.0]
# [25.0]
# [25.0]
# [27.0, 27.0]
# [27.0]
# [27.0]
# [27.0]
# [27.0]
# [27.0]
# [27.0]
# [28.0, 28.0]
# [28.0]
# [28.0]
# [28.0]
# [28.0]
# [28.0]
# [28.0]
# [29.0, 30.0]
# [30.0]
# [30.0]
# [30.0]
# [30.0]
# [30.0]
# [30.0]
# [26.0, 25.0]
# [25.0]
# [25.0]
# [25.0]
# [25.0]
# [25.0]
# [25.0]
# [24.0, 23.0]
# [24.0]
# [24.0]
# [24.0]
# [24.0]
# [24.0]
# [24.0]
# [26.0, 26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]
# [26.0]

# %%
df.shape
# Out:
# (121, 9)

# %%
df.head()
# Out:
#                                 eventId  chbid          xpos          ypos  \
# 0  11112018-2240-1_11112018-2240-1_1299      1  [26.0, 25.0]  [24.0, 24.0]
# 1  11112018-2240-1_11112018-2240-1_1299      2        [25.0]        [24.0]
# 2  11112018-2240-1_11112018-2240-1_1299      3        [25.0]        [24.0]
# 3  11112018-2240-1_11112018-2240-1_1299      4        [25.0]        [23.0]
# 4  11112018-2240-1_11112018-2240-1_1299      5        [25.0]        [23.0]
#
#         dt   digit  chipid  hardid  nhits
# 0  [1,100]  [3, 3]  [4, 2]  [7, 0]      2
# 1   [15.0]     [3]     [2]     [0]      1
# 2   [16.0]     [2]     [2]     [0]      1
# 3   [16.0]     [2]    [17]    [63]      1
# 4   [16.0]     [2]    [17]    [63]      1

# %%
indices = df[df.chbid == 1].index.tolist()
df['tmp'].update(pd.Series([[1,1]]*len(indices), index=indices))
df[df.chbid == 1].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-73257e30c86a> in <module>
#       1 indices = df[df.chbid == 1].index.tolist()
# ----> 2 df['tmp'].update(pd.Series([[1,1]]*len(indices), index=indices))
#       3 df[df.chbid == 1].head()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in update(self, other)
#    3015         mask = notna(other)
#    3016
# -> 3017         self._data = self._data.putmask(mask=mask, new=other, inplace=True)
#    3018         self._maybe_update_cacher()
#    3019
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/managers.py in putmask(self, **kwargs)
#     561
#     562     def putmask(self, **kwargs):
# --> 563         return self.apply("putmask", **kwargs)
#     564
#     565     def diff(self, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/blocks.py in putmask(self, mask, new, align, inplace, axis, transpose)
#    1049                 return nv
#    1050
# -> 1051             new_blocks = self.split_and_operate(mask, f, inplace)
#    1052             return new_blocks
#    1053
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/blocks.py in split_and_operate(self, mask, f, inplace)
#     477         if self.ndim == 1:
#     478             if mask.any():
# --> 479                 nv = f(mask, new_values, None)
#     480             else:
#     481                 nv = new_values if inplace else new_values.copy()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/blocks.py in f(m, v, i)
#    1046                     n = n.astype(dtype)
#    1047
# -> 1048                 nv = _putmask_smart(v, m, n)
#    1049                 return nv
#    1050
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _putmask_smart(v, m, n)
#    3389         # make sure that we have a nullable type
#    3390         # if we have nulls
# -> 3391         if not _isna_compat(v, nn[0]):
#    3392             pass
#    3393         elif not (is_float_dtype(nn.dtype) or is_integer_dtype(nn.dtype)):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/dtypes/missing.py in _isna_compat(arr, fill_value)
#     386     """
#     387     dtype = arr.dtype
# --> 388     if isna(fill_value):
#     389         return not (is_bool_dtype(dtype) or is_integer_dtype(dtype))
#     390     return True
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
pd.Series([[1,1]]*len(indices), index=indices)
# Out:
# 0      [1, 1]
# 7      [1, 1]
# 14     [1, 1]
# 22     [1, 1]
# 30     [1, 1]
# 37     [1, 1]
# 44     [1, 1]
# 51     [1, 1]
# 58     [1, 1]
# 65     [1, 1]
# 72     [1, 1]
# 79     [1, 1]
# 86     [1, 1]
# 93     [1, 1]
# 100    [1, 1]
# 107    [1, 1]
# 114    [1, 1]
# dtype: object

# %%
df['tmp'] = []*df.shape[0]

# %%
df
# Out:
#                                   eventId  chbid          xpos          ypos  \
# 0    11112018-2240-1_11112018-2240-1_1299      1  [26.0, 25.0]  [24.0, 24.0]
# 1    11112018-2240-1_11112018-2240-1_1299      2        [25.0]        [24.0]
# 2    11112018-2240-1_11112018-2240-1_1299      3        [25.0]        [24.0]
# 3    11112018-2240-1_11112018-2240-1_1299      4        [25.0]        [23.0]
# 4    11112018-2240-1_11112018-2240-1_1299      5        [25.0]        [23.0]
# ..                                    ...    ...           ...           ...
# 116   11112018-2240-1_11112018-2240-1_817      3        [26.0]        [28.0]
# 117   11112018-2240-1_11112018-2240-1_817      4        [26.0]        [28.0]
# 118   11112018-2240-1_11112018-2240-1_817      5        [26.0]        [28.0]
# 119   11112018-2240-1_11112018-2240-1_817      6        [26.0]        [28.0]
# 120   11112018-2240-1_11112018-2240-1_817      7        [26.0]        [28.0]
#
#          dt   digit  chipid  hardid  nhits            tmp
# 0    [1, 1]  [3, 3]  [4, 2]  [7, 0]      2  2.395528e-314
# 1    [15.0]     [3]     [2]     [0]      1  2.207540e-314
# 2    [16.0]     [2]     [2]     [0]      1  2.207540e-314
# 3    [16.0]     [2]    [17]    [63]      1  2.207540e-314
# 4    [16.0]     [2]    [17]    [63]      1  2.207540e-314
# ..      ...     ...     ...     ...    ...            ...
# 116  [14.0]     [2]     [3]    [39]      1  2.207540e-314
# 117  [13.0]     [1]    [11]    [52]      1  2.207540e-314
# 118  [14.0]     [2]    [11]    [52]      1  2.207540e-314
# 119  [15.0]     [3]    [11]    [52]      1  2.207540e-314
# 120  [14.0]     [2]    [11]    [52]      1  2.207540e-314
#
# [121 rows x 10 columns]
